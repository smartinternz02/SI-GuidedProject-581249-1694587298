# %% [markdown]
# # **ASSIGNMENT**-**2** [***21BCE9210***--**YANUMULA** **ROHITH**]

# %% [markdown]
# # **Installling** **Seaborn** **Library**

# %%
pip install seaborn

# %%
#importing seaborn as sns

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#Getting the Car_crashes dataset to work with data_visualisation

# %%
df=sns.load_dataset('car_crashes')

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # **BarChart**

# %%
import numpy as np
x = np.array(df["alcohol"])
y = np.array(df["ins_losses"])
plt.xlabel("Alcohol")
plt.ylabel("Insurance Losses")
plt.title("Scatter Plot of Alcohol vs. Insurance Losses")
plt.bar(x,y)
# Out:
# <BarContainer object of 51 artists>

# %%
x = np.array(df["speeding"])
y = np.array(df["ins_losses"])
plt.title("Scatter Plot of Alcohol vs. Insurance Losses")
plt.barh(x,y)
# Out:
# <BarContainer object of 51 artists>

# %% [markdown]
# # **PieChart**

# %%
import matplotlib.pyplot as plt

labels = ["Alcohol", "ins_losses"]
x = [60, 70]

fig, axes1 = plt.subplots(figsize=(10, 10))
axes1.pie(x, labels=labels, autopct='%0.2f%%', colors=["pink", "violet"])
axes1.legend(labels, loc="best")

plt.show()

# %%
#getting information of car_crashes dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# # **Scatter Plot**

# %%
sns.scatterplot(x='speeding',y='total',data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %%
#Inference here as speed increases total also increasing

# %%
sns.scatterplot(x='alcohol',y='total',data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='total'>

# %%
#Inference here as alcohol increases total increasing

# %%
sns.scatterplot(x='not_distracted',y='total',data=df)
# Out:
# <Axes: xlabel='not_distracted', ylabel='total'>

# %%
#Inference here as not_distracted increases total increasing

# %% [markdown]
# # **LinePlot**

# %%
sns.lineplot(x='speeding',y='total',data=df,ci=None)
# Out:
# <ipython-input-33-25c3c4d233ba>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='speeding',y='total',data=df,ci=None)
# <Axes: xlabel='speeding', ylabel='total'>

# %%
#Inference here as speed increases total increasing with up and downs

# %% [markdown]
# # **Distplot**

# %%
sns.distplot(df["alcohol"])
# Out:
# <ipython-input-35-281d56044cde>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["alcohol"])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # **Histplot**

# %%
sns.histplot(df["speeding"])
# Out:
# <Axes: xlabel='speeding', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# # Replot

# %%
sns.relplot(x="total",y="alcohol",data=df,hue="speeding")

# %%
#Inference here alcohol increases then total also increases and we are checking with speeding how it relates with that

# %%
df["alcohol"].value_counts()
# Out:
# 5.208     2
# 5.640     1
# 4.218     1
# 4.704     1
# 3.480     1
# 3.136     1
# 4.968     1
# 3.567     1
# 10.038    1
# 4.794     1
# 5.771     1
# 3.328     1
# 5.642     1
# 9.799     1
# 9.416     1
# 6.402     1
# 5.655     1
# 7.372     1
# 1.808     1
# 4.080     1
# 3.429     1
# 3.498     1
# 6.664     1
# 4.554     1
# 5.215     1
# 5.474     1
# 4.525     1
# 5.456     1
# 5.824     1
# 3.360     1
# 3.808     1
# 3.888     1
# 4.860     1
# 1.593     1
# 5.191     1
# 3.900     1
# 7.175     1
# 4.437     1
# 4.352     1
# 4.205     1
# 3.925     1
# 4.272     1
# 4.922     1
# 6.765     1
# 4.530     1
# 4.000     1
# 2.870     1
# 3.948     1
# 2.784     1
# 5.568     1
# Name: alcohol, dtype: int64

# %% [markdown]
# # **BarPlot**

# %%
sns.barplot(data=df,x="alcohol",y="not_distracted",ci=None)
# Out:
# <ipython-input-41-c836539ef2b1>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="alcohol",y="not_distracted",ci=None)
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
#inference from we get to know how alcohol is associate with not_distracted in barplot

# %%
xi=df.head(10)

# %%
sns.barplot(data=xi,x="alcohol",y="speeding",hue="not_distracted")
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
#inference from we get to know how alcohol is associate with not_distracted in barplot with 5 dataitems

# %% [markdown]
# # **Countplot**

# %%
sns.countplot(x="not_distracted",data=df)
# Out:
# <Axes: xlabel='not_distracted', ylabel='count'>

# %%
#Inference here we count for first all dataitems in dataset for not_distracted

# %%
sns.countplot(x="not_distracted",data=xi)
# Out:
# <Axes: xlabel='not_distracted', ylabel='count'>

# %%
#Inference here we count for first 5 dataitems in dataset for not_distracted

# %% [markdown]
# # **JointPlot**

# %%
sns.jointplot(x="alcohol",y="total",data=df)

# %%
#Inference here jointplot between alcohol and total as alchol increases total also increases

# %%
sns.jointplot(x="speeding",y="ins_losses",data=df)

# %% [markdown]
# # **BoxPlot**

# %%
yi=df.head(10)

# %%
sns.boxplot(x="total",y="speeding",data=df)
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %%
#Inference here boxplot between speeding and total from total dataset as speeding increase total also increases

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-57-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %% [markdown]
# # **HeatMap**

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
#Inference here it relates with eachother and find corelation with each
